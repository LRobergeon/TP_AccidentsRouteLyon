# %%
from sklearn.neural_network import MLPClassifier
from sklearn import preprocessing
from sklearn.model_selection import train_test_split 
from apyori import apriori
import os
import sys
import xgboost as xgb
import matplotlib.pyplot as plt
from sklearn.svm import LinearSVC
from sklearn.datasets import make_classification

# %%
printing_mode = True

# %% [markdown]
# On importe le travail préalable

# %%
# %run import_data

# %% [markdown]
# Les variables qui, d'un premier abord, semblent inutiles.

# %%
colonnes_inutiles = ['num_veh',
                                'Num_Acc']
""",
                                'locp',
                                'actp',
                                'etatp',
                                'catv',
                                'hrmn',
                                'mois',
                                'jour',
                                'catvopp',
                                'occutc',
                                'place']
"""
# Out:
# ",\n                                'locp',\n                                'actp',\n                                'etatp',\n                                'catv',\n                                'hrmn',\n                                'mois',\n                                'jour',\n                                'catvopp',\n                                'occutc',\n                                'place']\n"

# %%
merged_data = merged_data.drop(colonnes_inutiles,axis = 1)

# %%
df = pd.get_dummies(merged_data, columns = merged_data.columns)
results = list(apriori(df))

# %%
y = merged_data.grav

# %%
merged_data_sans_grav = merged_data.drop(['grav'],axis = 1)

# %%
for x in merged_data_sans_grav.columns:
    print(merged_data_sans_grav[x][0])

merged_data_sans_grav.columns
# Out:
# 201600000001
# 1.0
# 1
# 2
# 11.0
# 0.0
# 0.0
# 0.0
# 1983.0
# B02
# 0.0
# 7
# 0
# 0.0
# 0.0
# 1.0
# 1.0
# 2
# 1
# 1445
# 1
# 2
# 1
# 8
# 3
# 3
# 2
# 2
# 1
# Index(['Num_Acc', 'place', 'catu', 'sexe', 'secu', 'locp', 'actp', 'etatp',
#        'an_nais', 'num_veh', 'senc', 'catv', 'occutc', 'obs', 'obsm', 'choc',
#        'manv', 'mois', 'jour', 'hrmn', 'lum', 'agg', 'int', 'atm', 'col',
#        'mom', 'catvopp', 'catv_gen', 'catvopp_gen'],
#       dtype='object')

# %%
#min_max_scaler = preprocessing.MinMaxScaler()
#np_scaled = min_max_scaler.fit_transform(merged_data)
#merged_data = pd.DataFrame(np_scaled)

# %%
X_train, X_test, y_train, y_test = train_test_split(merged_data_sans_grav, 
                                                    y, 
                                                    test_size=0.2, 
                                                    random_state=42)

listing_apriori_bis = []
data_accident = merged_data[merged_data.grav == 4].drop('grav', axis = 1)



for indexe in data_accident.index:
    event = []
    for colonne in data_accident.columns:
        if not (data_accident[colonne][indexe] == 0):
            event.append(colonne + str(data_accident[colonne][indexe]))
    listing_apriori_bis.append(event)

len(listing_apriori_bis)



min_sup = 0.40
min_conf = 0.90
results = list(apriori(listing_apriori_bis, min_support = min_sup, min_confidence = min_conf))

print(len(results))

os.system('say "fini"')
# Out:
# 71
# 0

# %%
if printing_mode:
    for x in range(0,len(results)):
        print(results[x].items)
        print('support')
        print(results[x].support)
        print('confiance')
        print(results[x].ordered_statistics[0].confidence)
# Out:
# frozenset({'place1.0', 'catu1'})
# support
# 0.6602363809265045
# confiance
# 1.0
# frozenset({'catv_gen2', 'catv7'})
# support
# 0.6728705338948513
# confiance
# 1.0
# frozenset({'secu11.0', 'catv_gen2'})
# support
# 0.6037223203369108
# confiance
# 0.9493697927793207
# frozenset({'catvopp_gen2', 'catvopp7'})
# support
# 0.7335959788072273
# confiance
# 1.0
# frozenset({'agg1', 'catv_gen2', 'catv7'})
# support
# 0.43105556310283927
# confiance
# 1.0
# frozenset({'secu11.0', 'agg1', 'catv_gen2'})
# support
# 0.420595027849477
# confiance
# 0.9485294117647058
# frozenset({'catvopp_gen2', 'agg1', 'catvopp7'})
# support
# 0.4161119413123217
# confiance
# 1.0
# frozenset({'place1.0', 'atm1', 'catu1'})
# support
# 0.5249286781687271
# confiance
# 1.0
# frozenset({'catv7', 'catv_gen2', 'atm1'})
# support
# 0.5110718652357017
# confiance
# 1.0
# frozenset({'secu11.0', 'catv_gen2', 'atm1'})
# support
# 0.45673142236109227
# confiance
# 0.9462426118772868
# frozenset({'catvopp_gen2', 'atm1', 'catvopp7'})
# support
# 0.5659557125390572
# confiance
# 1.0
# frozenset({'catv_gen2', 'catv7', 'catu1'})
# support
# 0.4075533215595707
# confiance
# 1.0
# frozenset({'place1.0', 'catv7', 'catu1'})
# support
# 0.4075533215595707
# confiance
# 1.0
# frozenset({'place1.0', 'catv_gen2', 'catu1'})
# support
# 0.44464067382149164
# confiance
# 1.0
# frozenset({'secu11.0', 'catv_gen2', 'catu1'})
# support
# 0.4080967259883168
# confiance
# 0.9178124045218454
# frozenset({'catvopp_gen2', 'catvopp7', 'catu1'})
# support
# 0.46950142643662546
# confiance
# 1.0
# frozenset({'place1.0', 'catvopp7', 'catu1'})
# support
# 0.46950142643662546
# confiance
# 1.0
# frozenset({'catvopp_gen2', 'place1.0', 'catu1'})
# support
# 0.5211248471675044
# confiance
# 1.0
# frozenset({'place1.0', 'int1', 'catu1'})
# support
# 0.504143458769189
# confiance
# 1.0
# frozenset({'place1.0', 'lum1', 'catu1'})
# support
# 0.4700448308653716
# confiance
# 1.0
# frozenset({'place1.0', 'obsm2.0', 'catu1'})
# support
# 0.48281483494090477
# confiance
# 1.0
# frozenset({'place1.0', 'secu11.0', 'catu1'})
# support
# 0.4305121586740932
# confiance
# 1.0
# frozenset({'place1.0', 'sexe1', 'catu1'})
# support
# 0.4636598288276049
# confiance
# 1.0
# frozenset({'catv_gen2', 'catv7', 'catvopp7'})
# support
# 0.5538649639994566
# confiance
# 1.0
# frozenset({'catvopp_gen2', 'catv_gen2', 'catv7'})
# support
# 0.5929900828691754
# confiance
# 1.0
# frozenset({'int1', 'catv_gen2', 'catv7'})
# support
# 0.5325363401711724
# confiance
# 1.0
# frozenset({'catv_gen2', 'catv7', 'lum1'})
# support
# 0.45904089118326313
# confiance
# 1.0
# frozenset({'catv_gen2', 'catv7', 'obsm2.0'})
# support
# 0.42928949870941446
# confiance
# 1.0
# frozenset({'place1.0', 'catv_gen2', 'catv7'})
# support
# 0.4075533215595707
# confiance
# 1.0
# frozenset({'secu11.0', 'catv_gen2', 'catv7'})
# support
# 0.556310283928814
# confiance
# 1.0
# frozenset({'catvopp_gen2', 'catv7', 'catvopp7'})
# support
# 0.5538649639994566
# confiance
# 1.0
# frozenset({'secu11.0', 'catv7', 'catvopp7'})
# support
# 0.44925961146583343
# confiance
# 0.9193772588268
# frozenset({'catvopp_gen2', 'catv_gen2', 'catvopp7'})
# support
# 0.5806276321152017
# confiance
# 1.0
# frozenset({'secu11.0', 'catv_gen2', 'catvopp7'})
# support
# 0.47344110854503463
# confiance
# 0.9688629413400055
# frozenset({'catvopp_gen2', 'secu11.0', 'catv_gen2'})
# support
# 0.5223475071321831
# confiance
# 0.9690020161290323
# frozenset({'secu11.0', 'int1', 'catv_gen2'})
# support
# 0.47683738622469773
# confiance
# 0.9458367016976557
# frozenset({'secu11.0', 'catv_gen2', 'lum1'})
# support
# 0.41597609020513515
# confiance
# 0.9438964241676941
# frozenset({'secu11.0', 'catv_gen2', 'obsm2.0'})
# support
# 0.4279309876375492
# confiance
# 0.9135730858468677
# frozenset({'place1.0', 'secu11.0', 'catv_gen2'})
# support
# 0.4080967259883168
# confiance
# 0.9178124045218454
# frozenset({'catvopp_gen2', 'int1', 'catvopp7'})
# support
# 0.5576687950006792
# confiance
# 1.0
# frozenset({'catvopp_gen2', 'lum1', 'catvopp7'})
# support
# 0.5034642032332564
# confiance
# 1.0
# frozenset({'catvopp_gen2', 'obsm2.0', 'catvopp7'})
# support
# 0.4943621790517593
# confiance
# 1.0
# frozenset({'catvopp_gen2', 'place1.0', 'catvopp7'})
# support
# 0.46950142643662546
# confiance
# 1.0
# frozenset({'catvopp_gen2', 'secu11.0', 'catvopp7'})
# support
# 0.4886564325499253
# confiance
# 1.0
# frozenset({'catvopp_gen2', 'catvopp7', 'sexe1'})
# support
# 0.4523841869311235
# confiance
# 1.0
# frozenset({'catvopp_gen2', 'place1.0', 'atm1', 'catu1'})
# support
# 0.4064665127020785
# confiance
# 1.0
# frozenset({'catv7', 'catv_gen2', 'atm1', 'catvopp7'})
# support
# 0.4135307702757777
# confiance
# 1.0
# frozenset({'catvopp_gen2', 'catv7', 'catv_gen2', 'atm1'})
# support
# 0.44464067382149164
# confiance
# 1.0
# frozenset({'catv7', 'int1', 'catv_gen2', 'atm1'})
# support
# 0.4019834261649232
# confiance
# 1.0
# frozenset({'catv7', 'secu11.0', 'catv_gen2', 'atm1'})
# support
# 0.4241271566363266
# confiance
# 1.0
# frozenset({'catvopp_gen2', 'catv7', 'atm1', 'catvopp7'})
# support
# 0.4135307702757777
# confiance
# 1.0
# frozenset({'catvopp_gen2', 'catv_gen2', 'atm1', 'catvopp7'})
# support
# 0.4314631164243989
# confiance
# 1.0
# frozenset({'catvopp_gen2', 'int1', 'atm1', 'catvopp7'})
# support
# 0.42494226327944573
# confiance
# 1.0
# frozenset({'catvopp_gen2', 'lum1', 'atm1', 'catvopp7'})
# support
# 0.4116288547751664
# confiance
# 1.0
# frozenset({'place1.0', 'catv_gen2', 'catv7', 'catu1'})
# support
# 0.4075533215595707
# confiance
# 1.0
# frozenset({'place1.0', 'secu11.0', 'catv_gen2', 'catu1'})
# support
# 0.4080967259883168
# confiance
# 0.9178124045218454
# frozenset({'catvopp_gen2', 'place1.0', 'catvopp7', 'catu1'})
# support
# 0.46950142643662546
# confiance
# 1.0
# frozenset({'catvopp_gen2', 'catv_gen2', 'catv7', 'catvopp7'})
# support
# 0.5538649639994566
# confiance
# 1.0
# frozenset({'int1', 'catv_gen2', 'catv7', 'catvopp7'})
# support
# 0.4370330118190463
# confiance
# 1.0
# frozenset({'secu11.0', 'catv_gen2', 'catv7', 'catvopp7'})
# support
# 0.44925961146583343
# confiance
# 1.0
# frozenset({'catvopp_gen2', 'int1', 'catv_gen2', 'catv7'})
# support
# 0.47058823529411764
# confiance
# 1.0
# frozenset({'catvopp_gen2', 'secu11.0', 'catv_gen2', 'catv7'})
# support
# 0.48295068604809127
# confiance
# 1.0
# frozenset({'secu11.0', 'int1', 'catv_gen2', 'catv7'})
# support
# 0.43648960739030024
# confiance
# 1.0
# frozenset({'catvopp_gen2', 'int1', 'catv7', 'catvopp7'})
# support
# 0.4370330118190463
# confiance
# 1.0
# frozenset({'catvopp_gen2', 'secu11.0', 'catv7', 'catvopp7'})
# support
# 0.44925961146583343
# confiance
# 1.0
# frozenset({'catvopp_gen2', 'int1', 'catv_gen2', 'catvopp7'})
# support
# 0.45972014671919575
# confiance
# 1.0
# frozenset({'catvopp_gen2', 'secu11.0', 'catv_gen2', 'catvopp7'})
# support
# 0.47344110854503463
# confiance
# 1.0
# frozenset({'catvopp_gen2', 'secu11.0', 'int1', 'catv_gen2'})
# support
# 0.4128515147398451
# confiance
# 0.9672183322724379
# frozenset({'catv_gen2', 'atm1', 'catv7', 'catvopp_gen2', 'catvopp7'})
# support
# 0.4135307702757777
# confiance
# 1.0
# frozenset({'int1', 'catv_gen2', 'catv7', 'catvopp_gen2', 'catvopp7'})
# support
# 0.4370330118190463
# confiance
# 1.0
# frozenset({'secu11.0', 'catv_gen2', 'catv7', 'catvopp_gen2', 'catvopp7'})
# support
# 0.44925961146583343
# confiance
# 1.0

# %%
listing_apriori_bis
# Out:
# [['Num_Acc201600000004',
#   'place2.0',
#   'catu2',
#   'sexe1',
#   'secu23.0',
#   'an_nais1999.0',
#   'num_vehB02',
#   'catv32',
#   'choc1.0',
#   'manv1.0',
#   'mois8',
#   'jour15',
#   'hrmn1930',
#   'lum2',
#   'agg2',
#   'int1',
#   'atm7',
#   'col3',
#   'mom4',
#   'catvopp7',
#   'catv_gen1',
#   'catvopp_gen2'],
#  ['Num_Acc201600000007',
#   'place2.0',
#   'catu2',
#   'sexe1',
#   'secu21.0',
#   'an_nais2001.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv30',
#   'choc3.0',
#   'manv15.0',
#   'mois5',
#   'jour1',
#   'hrmn1145',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm7',
#   'col2',
#   'mom1',
#   'catvopp7',
#   'catv_gen1',
#   'catvopp_gen2'],
#  ['Num_Acc201600000016',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu21.0',
#   'an_nais1994.0',
#   'num_vehA01',
#   'catv33',
#   'obsm2.0',
#   'choc2.0',
#   'manv1.0',
#   'mois9',
#   'jour8',
#   'hrmn815',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col5',
#   'mom1',
#   'catvopp7',
#   'catv_gen1',
#   'catvopp_gen2'],
#  ['Num_Acc201600000019',
#   'place2.0',
#   'catu2',
#   'sexe2',
#   'secu11.0',
#   'an_nais1994.0',
#   'num_vehA01',
#   'catv7',
#   'obs16.0',
#   'obsm2.0',
#   'choc3.0',
#   'manv15.0',
#   'mois5',
#   'jour6',
#   'hrmn1915',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col5',
#   'mom4',
#   'catvopp33',
#   'catv_gen2',
#   'catvopp_gen1'],
#  ['Num_Acc201600000019',
#   'place3.0',
#   'catu2',
#   'sexe2',
#   'secu11.0',
#   'an_nais2014.0',
#   'num_vehA01',
#   'catv7',
#   'obs16.0',
#   'obsm2.0',
#   'choc3.0',
#   'manv15.0',
#   'mois5',
#   'jour6',
#   'hrmn1915',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col5',
#   'mom4',
#   'catvopp33',
#   'catv_gen2',
#   'catvopp_gen1'],
#  ['Num_Acc201600000021',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu21.0',
#   'an_nais1990.0',
#   'num_vehA01',
#   'catv30',
#   'obsm1.0',
#   'choc1.0',
#   'manv1.0',
#   'mois10',
#   'jour14',
#   'hrmn1145',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm1',
#   'col6',
#   'mom1',
#   'catvopp30',
#   'catv_gen1',
#   'catvopp_gen1'],
#  ['Num_Acc201600000030',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1972.0',
#   'num_vehA01',
#   'senc2.0',
#   'catv7',
#   'obsm1.0',
#   'choc2.0',
#   'manv2.0',
#   'mois5',
#   'jour6',
#   'hrmn1700',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm1',
#   'col6',
#   'mom3',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000050',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1940.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'manv21.0',
#   'mois9',
#   'jour8',
#   'hrmn1000',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col3',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000075',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1978.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois12',
#   'jour3',
#   'hrmn1745',
#   'lum5',
#   'agg2',
#   'int1',
#   'atm1',
#   'col1',
#   'mom3',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000078',
#   'place3.0',
#   'catu2',
#   'sexe1',
#   'secu13.0',
#   'an_nais1991.0',
#   'num_vehA01',
#   'catv7',
#   'mois7',
#   'jour23',
#   'hrmn600',
#   'lum2',
#   'agg1',
#   'int1',
#   'atm1',
#   'col7',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000078',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu13.0',
#   'an_nais1994.0',
#   'num_vehA01',
#   'catv7',
#   'mois7',
#   'jour23',
#   'hrmn600',
#   'lum2',
#   'agg1',
#   'int1',
#   'atm1',
#   'col7',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000078',
#   'place2.0',
#   'catu2',
#   'sexe1',
#   'secu13.0',
#   'an_nais1992.0',
#   'num_vehA01',
#   'catv7',
#   'mois7',
#   'jour23',
#   'hrmn600',
#   'lum2',
#   'agg1',
#   'int1',
#   'atm1',
#   'col7',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000084',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu42.0',
#   'an_nais1974.0',
#   'num_vehA02',
#   'senc2.0',
#   'catv1',
#   'obsm2.0',
#   'choc8.0',
#   'manv2.0',
#   'mois4',
#   'jour2',
#   'hrmn200',
#   'lum3',
#   'agg1',
#   'int1',
#   'atm1',
#   'col2',
#   'catvopp7',
#   'catv_gen1',
#   'catvopp_gen2'],
#  ['Num_Acc201600000092',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1997.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv7',
#   'obs13.0',
#   'choc1.0',
#   'manv1.0',
#   'mois4',
#   'jour5',
#   'hrmn1015',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col6',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000100',
#   'catu3',
#   'sexe1',
#   'locp2.0',
#   'actp1.0',
#   'etatp1.0',
#   'an_nais1990.0',
#   'num_vehA01',
#   'catv7',
#   'obsm1.0',
#   'choc2.0',
#   'manv15.0',
#   'mois3',
#   'jour9',
#   'hrmn2000',
#   'lum5',
#   'agg2',
#   'int1',
#   'atm1',
#   'col6',
#   'mom4',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000101',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1963.0',
#   'num_vehA01',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois4',
#   'jour14',
#   'hrmn1400',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col5',
#   'mom3',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000101',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1982.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'manv13.0',
#   'mois4',
#   'jour14',
#   'hrmn1400',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col5',
#   'mom3',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000101',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1985.0',
#   'num_vehC03',
#   'senc2.0',
#   'catv7',
#   'choc1.0',
#   'mois4',
#   'jour14',
#   'hrmn1400',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col5',
#   'mom3',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000110',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu13.0',
#   'an_nais1994.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv7',
#   'obs2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois11',
#   'jour26',
#   'hrmn1745',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm1',
#   'col6',
#   'mom3',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000112',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu13.0',
#   'an_nais1972.0',
#   'num_vehA01',
#   'senc2.0',
#   'catv7',
#   'choc3.0',
#   'manv1.0',
#   'mois12',
#   'jour2',
#   'hrmn745',
#   'lum2',
#   'agg2',
#   'int1',
#   'atm5',
#   'col7',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000113',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1948.0',
#   'num_vehA01',
#   'catv7',
#   'obs8.0',
#   'choc2.0',
#   'manv1.0',
#   'mois12',
#   'jour2',
#   'hrmn1345',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm5',
#   'col6',
#   'mom2',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000114',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1992.0',
#   'num_vehB02',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois12',
#   'jour5',
#   'hrmn815',
#   'lum1',
#   'agg2',
#   'int2',
#   'atm1',
#   'col3',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000115',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1997.0',
#   'num_vehA01',
#   'catv7',
#   'obs13.0',
#   'choc1.0',
#   'manv1.0',
#   'mois12',
#   'jour9',
#   'hrmn2000',
#   'lum3',
#   'agg1',
#   'int1',
#   'atm2',
#   'col7',
#   'mom4',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000116',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1954.0',
#   'num_vehA01',
#   'catv7',
#   'obs13.0',
#   'choc2.0',
#   'manv1.0',
#   'mois12',
#   'jour13',
#   'hrmn1530',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col6',
#   'mom3',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000122',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1998.0',
#   'num_vehA01',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'manv14.0',
#   'mois11',
#   'jour10',
#   'hrmn730',
#   'lum2',
#   'agg1',
#   'int1',
#   'atm1',
#   'col5',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000131',
#   'catu3',
#   'sexe2',
#   'locp4.0',
#   'actp3.0',
#   'etatp2.0',
#   'an_nais1947.0',
#   'num_vehA01',
#   'catv7',
#   'obsm1.0',
#   'choc2.0',
#   'manv1.0',
#   'mois10',
#   'jour16',
#   'hrmn1015',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm1',
#   'col6',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000182',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1996.0',
#   'num_vehB02',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois12',
#   'jour29',
#   'hrmn1730',
#   'lum3',
#   'agg1',
#   'int1',
#   'atm9',
#   'col1',
#   'mom3',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000186',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu21.0',
#   'an_nais1997.0',
#   'num_vehB02',
#   'catv31',
#   'obsm2.0',
#   'manv2.0',
#   'mois10',
#   'jour26',
#   'hrmn1745',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm5',
#   'col3',
#   'mom3',
#   'catvopp2',
#   'catv_gen1',
#   'catvopp_gen1'],
#  ['Num_Acc201600000193',
#   'place5.0',
#   'catu2',
#   'sexe2',
#   'secu13.0',
#   'an_nais2005.0',
#   'num_vehA01',
#   'senc2.0',
#   'catv38',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois11',
#   'jour15',
#   'hrmn745',
#   'lum2',
#   'agg1',
#   'int1',
#   'atm5',
#   'col1',
#   'mom1',
#   'catvopp17',
#   'catv_gen3',
#   'catvopp_gen3'],
#  ['Num_Acc201600000193',
#   'place5.0',
#   'catu2',
#   'sexe2',
#   'secu13.0',
#   'an_nais2004.0',
#   'num_vehA01',
#   'senc2.0',
#   'catv38',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois11',
#   'jour15',
#   'hrmn745',
#   'lum2',
#   'agg1',
#   'int1',
#   'atm5',
#   'col1',
#   'mom1',
#   'catvopp17',
#   'catv_gen3',
#   'catvopp_gen3'],
#  ['Num_Acc201600000193',
#   'place5.0',
#   'catu2',
#   'sexe1',
#   'secu13.0',
#   'an_nais2004.0',
#   'num_vehA01',
#   'senc2.0',
#   'catv38',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois11',
#   'jour15',
#   'hrmn745',
#   'lum2',
#   'agg1',
#   'int1',
#   'atm5',
#   'col1',
#   'mom1',
#   'catvopp17',
#   'catv_gen3',
#   'catvopp_gen3'],
#  ['Num_Acc201600000193',
#   'place5.0',
#   'catu2',
#   'sexe2',
#   'secu13.0',
#   'an_nais2003.0',
#   'num_vehA01',
#   'senc2.0',
#   'catv38',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois11',
#   'jour15',
#   'hrmn745',
#   'lum2',
#   'agg1',
#   'int1',
#   'atm5',
#   'col1',
#   'mom1',
#   'catvopp17',
#   'catv_gen3',
#   'catvopp_gen3'],
#  ['Num_Acc201600000193',
#   'place2.0',
#   'catu2',
#   'sexe1',
#   'secu13.0',
#   'an_nais2004.0',
#   'num_vehA01',
#   'senc2.0',
#   'catv38',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois11',
#   'jour15',
#   'hrmn745',
#   'lum2',
#   'agg1',
#   'int1',
#   'atm5',
#   'col1',
#   'mom1',
#   'catvopp17',
#   'catv_gen3',
#   'catvopp_gen3'],
#  ['Num_Acc201600000193',
#   'place2.0',
#   'catu2',
#   'sexe2',
#   'secu13.0',
#   'an_nais2003.0',
#   'num_vehA01',
#   'senc2.0',
#   'catv38',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois11',
#   'jour15',
#   'hrmn745',
#   'lum2',
#   'agg1',
#   'int1',
#   'atm5',
#   'col1',
#   'mom1',
#   'catvopp17',
#   'catv_gen3',
#   'catvopp_gen3'],
#  ['Num_Acc201600000193',
#   'place2.0',
#   'catu2',
#   'sexe1',
#   'secu13.0',
#   'an_nais2003.0',
#   'num_vehA01',
#   'senc2.0',
#   'catv38',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois11',
#   'jour15',
#   'hrmn745',
#   'lum2',
#   'agg1',
#   'int1',
#   'atm5',
#   'col1',
#   'mom1',
#   'catvopp17',
#   'catv_gen3',
#   'catvopp_gen3'],
#  ['Num_Acc201600000193',
#   'place2.0',
#   'catu2',
#   'sexe2',
#   'secu13.0',
#   'an_nais2002.0',
#   'num_vehA01',
#   'senc2.0',
#   'catv38',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois11',
#   'jour15',
#   'hrmn745',
#   'lum2',
#   'agg1',
#   'int1',
#   'atm5',
#   'col1',
#   'mom1',
#   'catvopp17',
#   'catv_gen3',
#   'catvopp_gen3'],
#  ['Num_Acc201600000193',
#   'place2.0',
#   'catu2',
#   'sexe2',
#   'secu13.0',
#   'an_nais2005.0',
#   'num_vehA01',
#   'senc2.0',
#   'catv38',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois11',
#   'jour15',
#   'hrmn745',
#   'lum2',
#   'agg1',
#   'int1',
#   'atm5',
#   'col1',
#   'mom1',
#   'catvopp17',
#   'catv_gen3',
#   'catvopp_gen3'],
#  ['Num_Acc201600000194',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1966.0',
#   'num_vehC03',
#   'senc2.0',
#   'catv10',
#   'obs1.0',
#   'choc1.0',
#   'manv2.0',
#   'mois1',
#   'jour7',
#   'hrmn1900',
#   'lum3',
#   'agg1',
#   'int1',
#   'atm6',
#   'col4',
#   'mom4',
#   'catvopp17',
#   'catv_gen2',
#   'catvopp_gen3'],
#  ['Num_Acc201600000200',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1989.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv10',
#   'choc5.0',
#   'manv1.0',
#   'mois7',
#   'jour24',
#   'hrmn1700',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col3',
#   'mom3',
#   'catvopp33',
#   'catv_gen2',
#   'catvopp_gen1'],
#  ['Num_Acc201600000201',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1958.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv10',
#   'obsm2.0',
#   'choc5.0',
#   'manv2.0',
#   'mois8',
#   'jour13',
#   'hrmn2215',
#   'lum3',
#   'agg1',
#   'int1',
#   'atm1',
#   'col2',
#   'mom5',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000201',
#   'place2.0',
#   'catu2',
#   'sexe2',
#   'secu11.0',
#   'an_nais1957.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv10',
#   'obsm2.0',
#   'choc5.0',
#   'manv2.0',
#   'mois8',
#   'jour13',
#   'hrmn2215',
#   'lum3',
#   'agg1',
#   'int1',
#   'atm1',
#   'col2',
#   'mom5',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000202',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1994.0',
#   'num_vehC02',
#   'senc1.0',
#   'catv10',
#   'obsm2.0',
#   'choc2.0',
#   'manv2.0',
#   'mois9',
#   'jour28',
#   'hrmn745',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col2',
#   'mom1',
#   'catvopp17',
#   'catv_gen2',
#   'catvopp_gen3'],
#  ['Num_Acc201600000205',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1973.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv7',
#   'choc9.0',
#   'manv1.0',
#   'mois12',
#   'jour29',
#   'hrmn1830',
#   'lum3',
#   'agg1',
#   'int1',
#   'atm1',
#   'col3',
#   'mom4',
#   'catvopp15',
#   'catv_gen2',
#   'catvopp_gen3'],
#  ['Num_Acc201600000209',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu21.0',
#   'an_nais1955.0',
#   'num_vehA01',
#   'catv1',
#   'obs1.0',
#   'choc1.0',
#   'manv1.0',
#   'mois6',
#   'jour7',
#   'hrmn930',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm1',
#   'col6',
#   'mom1',
#   'catvopp1',
#   'catv_gen1',
#   'catvopp_gen1'],
#  ['Num_Acc201600000211',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu21.0',
#   'an_nais1992.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv33',
#   'manv2.0',
#   'mois7',
#   'jour15',
#   'hrmn1145',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col7',
#   'mom1',
#   'catvopp33',
#   'catv_gen1',
#   'catvopp_gen1'],
#  ['Num_Acc201600000215',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1967.0',
#   'num_vehA01',
#   'catv7',
#   'obsm2.0',
#   'choc7.0',
#   'manv19.0',
#   'mois11',
#   'jour30',
#   'hrmn1415',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm1',
#   'col3',
#   'mom3',
#   'catvopp15',
#   'catv_gen2',
#   'catvopp_gen3'],
#  ['Num_Acc201600000215',
#   'place4.0',
#   'catu2',
#   'sexe2',
#   'secu11.0',
#   'an_nais1993.0',
#   'num_vehA01',
#   'catv7',
#   'obsm2.0',
#   'choc7.0',
#   'manv19.0',
#   'mois11',
#   'jour30',
#   'hrmn1415',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm1',
#   'col3',
#   'mom3',
#   'catvopp15',
#   'catv_gen2',
#   'catvopp_gen3'],
#  ['Num_Acc201600000215',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1987.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv15',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois11',
#   'jour30',
#   'hrmn1415',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm1',
#   'col3',
#   'mom3',
#   'catvopp7',
#   'catv_gen3',
#   'catvopp_gen2'],
#  ['Num_Acc201600000228',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1949.0',
#   'num_vehA01',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'manv15.0',
#   'mois12',
#   'jour10',
#   'hrmn1845',
#   'lum3',
#   'agg1',
#   'int1',
#   'atm9',
#   'col1',
#   'mom4',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000230',
#   'place2.0',
#   'catu2',
#   'sexe1',
#   'secu11.0',
#   'an_nais1982.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv10',
#   'obs1.0',
#   'choc3.0',
#   'manv9.0',
#   'mois7',
#   'jour26',
#   'hrmn1030',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col6',
#   'mom1',
#   'catvopp10',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000230',
#   'place8.0',
#   'catu2',
#   'sexe1',
#   'secu11.0',
#   'an_nais1993.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv10',
#   'obs1.0',
#   'choc3.0',
#   'manv9.0',
#   'mois7',
#   'jour26',
#   'hrmn1030',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col6',
#   'mom1',
#   'catvopp10',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000238',
#   'place2.0',
#   'catu2',
#   'sexe2',
#   'secu11.0',
#   'an_nais1956.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc6.0',
#   'manv13.0',
#   'mois8',
#   'jour21',
#   'hrmn1215',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm2',
#   'col1',
#   'mom2',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000238',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1984.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois8',
#   'jour21',
#   'hrmn1215',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm2',
#   'col1',
#   'mom2',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000239',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1995.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv7',
#   'obs6.0',
#   'choc1.0',
#   'manv1.0',
#   'mois3',
#   'jour7',
#   'hrmn1715',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm8',
#   'col6',
#   'mom3',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000240',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1955.0',
#   'num_vehD04',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc4.0',
#   'manv2.0',
#   'mois4',
#   'jour22',
#   'hrmn1815',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col4',
#   'mom4',
#   'catvopp17',
#   'catv_gen2',
#   'catvopp_gen3'],
#  ['Num_Acc201600000243',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1976.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv7',
#   'obs6.0',
#   'choc1.0',
#   'manv1.0',
#   'mois11',
#   'jour21',
#   'hrmn800',
#   'lum2',
#   'agg1',
#   'int1',
#   'atm1',
#   'col6',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000244',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1982.0',
#   'num_vehA01',
#   'senc2.0',
#   'catv7',
#   'obsm1.0',
#   'choc1.0',
#   'manv1.0',
#   'mois12',
#   'jour6',
#   'hrmn745',
#   'lum2',
#   'agg2',
#   'int1',
#   'atm1',
#   'col6',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000245',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1988.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois3',
#   'jour13',
#   'hrmn1330',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col1',
#   'mom2',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000246',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1968.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv10',
#   'choc6.0',
#   'manv1.0',
#   'mois7',
#   'jour30',
#   'hrmn1200',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm1',
#   'col3',
#   'mom2',
#   'catvopp33',
#   'catv_gen2',
#   'catvopp_gen1'],
#  ['Num_Acc201600000248',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu21.0',
#   'an_nais1980.0',
#   'num_vehA01',
#   'catv31',
#   'choc2.0',
#   'manv1.0',
#   'mois4',
#   'jour10',
#   'hrmn1330',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm7',
#   'col7',
#   'mom2',
#   'catvopp31',
#   'catv_gen1',
#   'catvopp_gen1'],
#  ['Num_Acc201600000255',
#   'place2.0',
#   'catu2',
#   'sexe2',
#   'secu11.0',
#   'an_nais1998.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv10',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois4',
#   'jour17',
#   'hrmn1400',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col5',
#   'mom3',
#   'catvopp33',
#   'catv_gen2',
#   'catvopp_gen1'],
#  ['Num_Acc201600000257',
#   'place2.0',
#   'catu2',
#   'sexe1',
#   'secu11.0',
#   'an_nais1957.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv14',
#   'obsm2.0',
#   'choc6.0',
#   'manv1.0',
#   'mois4',
#   'jour29',
#   'hrmn1015',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col1',
#   'mom1',
#   'catvopp17',
#   'catv_gen3',
#   'catvopp_gen3'],
#  ['Num_Acc201600000257',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1974.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv14',
#   'obsm2.0',
#   'choc6.0',
#   'manv1.0',
#   'mois4',
#   'jour29',
#   'hrmn1015',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col1',
#   'mom1',
#   'catvopp17',
#   'catv_gen3',
#   'catvopp_gen3'],
#  ['Num_Acc201600000260',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1989.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc5.0',
#   'manv17.0',
#   'mois5',
#   'jour26',
#   'hrmn1545',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col1',
#   'mom3',
#   'catvopp10',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000262',
#   'place2.0',
#   'catu2',
#   'sexe1',
#   'secu11.0',
#   'an_nais1999.0',
#   'num_vehA01',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois10',
#   'jour9',
#   'hrmn345',
#   'lum5',
#   'agg2',
#   'int1',
#   'atm1',
#   'col3',
#   'catvopp10',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000262',
#   'place2.0',
#   'catu2',
#   'sexe2',
#   'secu11.0',
#   'an_nais1980.0',
#   'num_vehB02',
#   'catv10',
#   'obsm2.0',
#   'choc3.0',
#   'mois10',
#   'jour9',
#   'hrmn345',
#   'lum5',
#   'agg2',
#   'int1',
#   'atm1',
#   'col3',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000266',
#   'place2.0',
#   'catu2',
#   'sexe1',
#   'secu21.0',
#   'an_nais1998.0',
#   'num_vehA01',
#   'senc2.0',
#   'catv30',
#   'obsm6.0',
#   'choc1.0',
#   'manv1.0',
#   'mois9',
#   'jour21',
#   'hrmn2045',
#   'lum3',
#   'agg1',
#   'int1',
#   'atm1',
#   'col6',
#   'mom4',
#   'catvopp30',
#   'catv_gen1',
#   'catvopp_gen1'],
#  ['Num_Acc201600000266',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu21.0',
#   'an_nais1997.0',
#   'num_vehA01',
#   'senc2.0',
#   'catv30',
#   'obsm6.0',
#   'choc1.0',
#   'manv1.0',
#   'mois9',
#   'jour21',
#   'hrmn2045',
#   'lum3',
#   'agg1',
#   'int1',
#   'atm1',
#   'col6',
#   'mom4',
#   'catvopp30',
#   'catv_gen1',
#   'catvopp_gen1'],
#  ['Num_Acc201600000267',
#   'catu3',
#   'sexe2',
#   'locp4.0',
#   'actp3.0',
#   'etatp2.0',
#   'an_nais2013.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv7',
#   'obsm1.0',
#   'choc1.0',
#   'manv1.0',
#   'mois6',
#   'jour30',
#   'hrmn1000',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm3',
#   'col6',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000270',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1990.0',
#   'num_vehB02',
#   'catv7',
#   'choc7.0',
#   'manv1.0',
#   'mois10',
#   'jour8',
#   'hrmn1930',
#   'lum5',
#   'agg2',
#   'int1',
#   'atm1',
#   'col3',
#   'mom4',
#   'catvopp30',
#   'catv_gen2',
#   'catvopp_gen1'],
#  ['Num_Acc201600000272',
#   'place2.0',
#   'catu2',
#   'sexe1',
#   'secu21.0',
#   'an_nais1963.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv33',
#   'obsm2.0',
#   'choc1.0',
#   'manv13.0',
#   'mois1',
#   'jour31',
#   'hrmn1645',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm2',
#   'col1',
#   'mom3',
#   'catvopp32',
#   'catv_gen1',
#   'catvopp_gen1'],
#  ['Num_Acc201600000272',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu21.0',
#   'an_nais1951.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv32',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois1',
#   'jour31',
#   'hrmn1645',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm2',
#   'col1',
#   'mom3',
#   'catvopp33',
#   'catv_gen1',
#   'catvopp_gen1'],
#  ['Num_Acc201600000274',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1997.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois2',
#   'jour1',
#   'hrmn1430',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm6',
#   'col1',
#   'mom3',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000288',
#   'place2.0',
#   'catu2',
#   'sexe2',
#   'secu11.0',
#   'an_nais1968.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois12',
#   'jour27',
#   'hrmn1830',
#   'lum3',
#   'agg2',
#   'int1',
#   'atm8',
#   'col1',
#   'mom4',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000293',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu13.0',
#   'an_nais1987.0',
#   'num_vehB02',
#   'catv7',
#   'obsm2.0',
#   'choc6.0',
#   'manv1.0',
#   'mois3',
#   'jour19',
#   'hrmn1215',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm1',
#   'col3',
#   'mom2',
#   'catvopp3',
#   'catv_gen2'],
#  ['Num_Acc201600000295',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu21.0',
#   'an_nais2001.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv1',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois4',
#   'jour13',
#   'hrmn1645',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col2',
#   'mom3',
#   'catvopp10',
#   'catv_gen1',
#   'catvopp_gen2'],
#  ['Num_Acc201600000296',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu21.0',
#   'an_nais1972.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv31',
#   'manv1.0',
#   'mois4',
#   'jour16',
#   'hrmn200',
#   'lum5',
#   'agg2',
#   'int1',
#   'atm1',
#   'col1',
#   'catvopp30',
#   'catv_gen1',
#   'catvopp_gen1'],
#  ['Num_Acc201600000297',
#   'place2.0',
#   'catu2',
#   'sexe2',
#   'secu11.0',
#   'an_nais2000.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'mois4',
#   'jour15',
#   'hrmn2115',
#   'lum3',
#   'agg1',
#   'int1',
#   'atm2',
#   'col1',
#   'mom4',
#   'catvopp10',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000303',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1978.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'manv13.0',
#   'mois9',
#   'jour13',
#   'hrmn2000',
#   'lum2',
#   'agg1',
#   'int1',
#   'atm1',
#   'col1',
#   'mom4',
#   'catvopp10',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000307',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1944.0',
#   'num_vehA01',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'manv9.0',
#   'mois11',
#   'jour1',
#   'hrmn1815',
#   'lum2',
#   'agg1',
#   'int1',
#   'atm1',
#   'col3',
#   'mom4',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000334',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu21.0',
#   'an_nais1972.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv33',
#   'obsm1.0',
#   'choc2.0',
#   'manv21.0',
#   'mois1',
#   'jour8',
#   'hrmn900',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm1',
#   'col6',
#   'mom1',
#   'catvopp7',
#   'catv_gen1',
#   'catvopp_gen2'],
#  ['Num_Acc201600000337',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu21.0',
#   'an_nais1996.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv33',
#   'choc8.0',
#   'manv21.0',
#   'mois2',
#   'jour26',
#   'hrmn1945',
#   'lum5',
#   'agg2',
#   'int1',
#   'atm1',
#   'col7',
#   'mom4',
#   'catvopp33',
#   'catv_gen1',
#   'catvopp_gen1'],
#  ['Num_Acc201600000340',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1985.0',
#   'num_vehB02',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois5',
#   'jour11',
#   'hrmn1200',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm1',
#   'col3',
#   'mom2',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000340',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1992.0',
#   'num_vehA01',
#   'catv7',
#   'obsm2.0',
#   'choc2.0',
#   'manv11.0',
#   'mois5',
#   'jour11',
#   'hrmn1200',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm1',
#   'col3',
#   'mom2',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000350',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1972.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'mois7',
#   'jour15',
#   'hrmn1315',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col1',
#   'mom2',
#   'catvopp10',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000352',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1949.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois10',
#   'jour23',
#   'hrmn2045',
#   'lum3',
#   'agg1',
#   'int2',
#   'atm3',
#   'col5',
#   'mom4',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000354',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu21.0',
#   'an_nais1985.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv30',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois2',
#   'jour5',
#   'hrmn730',
#   'lum2',
#   'agg2',
#   'int2',
#   'atm2',
#   'col3',
#   'mom1',
#   'catvopp7',
#   'catv_gen1',
#   'catvopp_gen2'],
#  ['Num_Acc201600000354',
#   'place2.0',
#   'catu2',
#   'sexe1',
#   'secu21.0',
#   'an_nais1990.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv30',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois2',
#   'jour5',
#   'hrmn730',
#   'lum2',
#   'agg2',
#   'int2',
#   'atm2',
#   'col3',
#   'mom1',
#   'catvopp7',
#   'catv_gen1',
#   'catvopp_gen2'],
#  ['Num_Acc201600000359',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1991.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'manv13.0',
#   'mois7',
#   'jour1',
#   'hrmn1815',
#   'lum1',
#   'agg1',
#   'int2',
#   'atm1',
#   'col3',
#   'mom4',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000360',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1956.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois10',
#   'jour8',
#   'hrmn1415',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col3',
#   'mom3',
#   'catvopp30',
#   'catv_gen2',
#   'catvopp_gen1'],
#  ['Num_Acc201600000362',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu13.0',
#   'an_nais1985.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv10',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois2',
#   'jour15',
#   'hrmn1245',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col1',
#   'mom2',
#   'catvopp2',
#   'catv_gen2',
#   'catvopp_gen1'],
#  ['Num_Acc201600000366',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1972.0',
#   'num_vehA01',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'manv13.0',
#   'mois1',
#   'jour3',
#   'hrmn100',
#   'lum3',
#   'agg1',
#   'int1',
#   'atm3',
#   'col3',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000366',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1976.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois1',
#   'jour3',
#   'hrmn100',
#   'lum3',
#   'agg1',
#   'int1',
#   'atm3',
#   'col3',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000367',
#   'place2.0',
#   'catu2',
#   'sexe1',
#   'secu11.0',
#   'an_nais2001.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv7',
#   'obs13.0',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois2',
#   'jour27',
#   'hrmn1215',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col1',
#   'mom2',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000368',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1972.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv10',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois4',
#   'jour26',
#   'hrmn845',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col1',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000370',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1944.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'manv9.0',
#   'mois7',
#   'jour18',
#   'hrmn1200',
#   'lum1',
#   'agg1',
#   'int3',
#   'atm1',
#   'col3',
#   'mom2',
#   'catvopp30',
#   'catv_gen2',
#   'catvopp_gen1'],
#  ['Num_Acc201600000371',
#   'place3.0',
#   'catu2',
#   'sexe2',
#   'secu11.0',
#   'an_nais1946.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois11',
#   'jour3',
#   'hrmn1915',
#   'lum4',
#   'agg1',
#   'int1',
#   'atm8',
#   'col1',
#   'mom4',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000373',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1996.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'manv13.0',
#   'mois11',
#   'jour16',
#   'hrmn1330',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col1',
#   'mom2',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000373',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1972.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois11',
#   'jour16',
#   'hrmn1330',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col1',
#   'mom2',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000375',
#   'place2.0',
#   'catu2',
#   'sexe1',
#   'secu21.0',
#   'an_nais1978.0',
#   'num_vehA01',
#   'senc2.0',
#   'catv33',
#   'obs13.0',
#   'choc1.0',
#   'manv13.0',
#   'mois10',
#   'jour3',
#   'hrmn1500',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col7',
#   'mom3',
#   'catvopp33',
#   'catv_gen1',
#   'catvopp_gen1'],
#  ['Num_Acc201600000380',
#   'place2.0',
#   'catu2',
#   'sexe1',
#   'secu12.0',
#   'an_nais1982.0',
#   'num_vehA01',
#   'senc2.0',
#   'catv7',
#   'obs16.0',
#   'choc9.0',
#   'manv14.0',
#   'mois6',
#   'jour15',
#   'hrmn2245',
#   'lum3',
#   'agg1',
#   'int1',
#   'atm2',
#   'col7',
#   'mom5',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000382',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1986.0',
#   'num_vehA01',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois3',
#   'jour11',
#   'hrmn415',
#   'lum3',
#   'agg1',
#   'int3',
#   'atm1',
#   'col3',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000384',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu13.0',
#   'an_nais1990.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc6.0',
#   'manv15.0',
#   'mois4',
#   'jour21',
#   'hrmn1730',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col3',
#   'mom3',
#   'catvopp10',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000386',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu21.0',
#   'an_nais1968.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv2',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois3',
#   'jour3',
#   'hrmn1700',
#   'lum1',
#   'agg2',
#   'int3',
#   'atm2',
#   'col1',
#   'mom3',
#   'catvopp7',
#   'catv_gen1',
#   'catvopp_gen2'],
#  ['Num_Acc201600000387',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1967.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv10',
#   'mois3',
#   'jour26',
#   'hrmn1030',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col1',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000387',
#   'place2.0',
#   'catu2',
#   'sexe1',
#   'secu11.0',
#   'an_nais1977.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv10',
#   'mois3',
#   'jour26',
#   'hrmn1030',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col1',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000393',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1989.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois6',
#   'jour9',
#   'hrmn1745',
#   'lum1',
#   'agg1',
#   'int2',
#   'atm1',
#   'col3',
#   'mom3',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000393',
#   'place2.0',
#   'catu2',
#   'sexe1',
#   'secu11.0',
#   'an_nais1994.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois6',
#   'jour9',
#   'hrmn1745',
#   'lum1',
#   'agg1',
#   'int2',
#   'atm1',
#   'col3',
#   'mom3',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000394',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1996.0',
#   'num_vehA01',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc2.0',
#   'manv15.0',
#   'mois8',
#   'jour29',
#   'hrmn2345',
#   'lum4',
#   'agg1',
#   'int3',
#   'atm1',
#   'col1',
#   'mom5',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000394',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1973.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc6.0',
#   'manv1.0',
#   'mois8',
#   'jour29',
#   'hrmn2345',
#   'lum4',
#   'agg1',
#   'int3',
#   'atm1',
#   'col1',
#   'mom5',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000399',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1987.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois5',
#   'jour21',
#   'hrmn1645',
#   'lum1',
#   'agg1',
#   'int2',
#   'atm1',
#   'col3',
#   'mom3',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000402',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1975.0',
#   'num_vehA01',
#   'senc2.0',
#   'catv7',
#   'obs3.0',
#   'obsm2.0',
#   'choc3.0',
#   'manv13.0',
#   'mois11',
#   'jour7',
#   'hrmn1600',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col5',
#   'mom3',
#   'catvopp17',
#   'catv_gen2',
#   'catvopp_gen3'],
#  ['Num_Acc201600000402',
#   'place2.0',
#   'catu2',
#   'sexe2',
#   'secu11.0',
#   'an_nais1982.0',
#   'num_vehA01',
#   'senc2.0',
#   'catv7',
#   'obs3.0',
#   'obsm2.0',
#   'choc3.0',
#   'manv13.0',
#   'mois11',
#   'jour7',
#   'hrmn1600',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col5',
#   'mom3',
#   'catvopp17',
#   'catv_gen2',
#   'catvopp_gen3'],
#  ['Num_Acc201600000403',
#   'place4.0',
#   'catu2',
#   'sexe1',
#   'secu11.0',
#   'an_nais1997.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv7',
#   'obs6.0',
#   'choc1.0',
#   'manv13.0',
#   'mois11',
#   'jour19',
#   'hrmn600',
#   'lum3',
#   'agg2',
#   'int1',
#   'atm1',
#   'col6',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000404',
#   'place2.0',
#   'catu2',
#   'sexe2',
#   'secu11.0',
#   'an_nais1966.0',
#   'num_vehB02',
#   'catv7',
#   'choc4.0',
#   'manv1.0',
#   'mois2',
#   'jour22',
#   'hrmn915',
#   'lum1',
#   'agg2',
#   'int4',
#   'atm1',
#   'col2',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000404',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1956.0',
#   'num_vehB02',
#   'catv7',
#   'choc4.0',
#   'manv1.0',
#   'mois2',
#   'jour22',
#   'hrmn915',
#   'lum1',
#   'agg2',
#   'int4',
#   'atm1',
#   'col2',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000406',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu21.0',
#   'an_nais1994.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv33',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois5',
#   'jour5',
#   'hrmn1700',
#   'lum1',
#   'agg1',
#   'int2',
#   'atm1',
#   'col3',
#   'mom3',
#   'catvopp7',
#   'catv_gen1',
#   'catvopp_gen2'],
#  ['Num_Acc201600000407',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1996.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc9.0',
#   'manv9.0',
#   'mois7',
#   'jour24',
#   'hrmn2245',
#   'lum3',
#   'agg1',
#   'int1',
#   'atm1',
#   'col3',
#   'mom5',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000407',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1977.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc6.0',
#   'manv1.0',
#   'mois7',
#   'jour24',
#   'hrmn2245',
#   'lum3',
#   'agg1',
#   'int1',
#   'atm1',
#   'col3',
#   'mom5',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000407',
#   'place2.0',
#   'catu2',
#   'sexe2',
#   'secu11.0',
#   'an_nais1981.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc6.0',
#   'manv1.0',
#   'mois7',
#   'jour24',
#   'hrmn2245',
#   'lum3',
#   'agg1',
#   'int1',
#   'atm1',
#   'col3',
#   'mom5',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000408',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1987.0',
#   'num_vehA01',
#   'senc2.0',
#   'catv10',
#   'obsm2.0',
#   'choc3.0',
#   'manv13.0',
#   'mois8',
#   'jour16',
#   'hrmn1945',
#   'lum2',
#   'agg1',
#   'int1',
#   'atm7',
#   'col1',
#   'mom4',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000409',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1985.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois10',
#   'jour23',
#   'hrmn2030',
#   'lum3',
#   'agg1',
#   'int1',
#   'atm3',
#   'col1',
#   'mom4',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000410',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1995.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc2.0',
#   'manv17.0',
#   'mois11',
#   'jour24',
#   'hrmn1230',
#   'lum1',
#   'agg1',
#   'int3',
#   'atm1',
#   'col2',
#   'mom2',
#   'catvopp2',
#   'catv_gen2',
#   'catvopp_gen1'],
#  ['Num_Acc201600000411',
#   'catu3',
#   'sexe1',
#   'locp2.0',
#   'actp3.0',
#   'etatp3.0',
#   'an_nais2003.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv7',
#   'obsm1.0',
#   'choc1.0',
#   'manv1.0',
#   'mois4',
#   'jour18',
#   'hrmn815',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm1',
#   'col6',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000411',
#   'catu3',
#   'sexe1',
#   'locp2.0',
#   'actp3.0',
#   'etatp3.0',
#   'an_nais2000.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv7',
#   'obsm1.0',
#   'choc1.0',
#   'manv1.0',
#   'mois4',
#   'jour18',
#   'hrmn815',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm1',
#   'col6',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000412',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu21.0',
#   'an_nais2001.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv2',
#   'choc1.0',
#   'manv1.0',
#   'mois5',
#   'jour1',
#   'hrmn1445',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm1',
#   'col3',
#   'mom3',
#   'catvopp7',
#   'catv_gen1',
#   'catvopp_gen2'],
#  ['Num_Acc201600000415',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu22.0',
#   'an_nais1999.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv1',
#   'choc8.0',
#   'manv1.0',
#   'mois8',
#   'jour26',
#   'hrmn930',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col5',
#   'mom1',
#   'catvopp10',
#   'catv_gen1',
#   'catvopp_gen2'],
#  ['Num_Acc201600000424',
#   'catu3',
#   'sexe1',
#   'locp1.0',
#   'actp3.0',
#   'etatp2.0',
#   'an_nais1981.0',
#   'num_vehA01',
#   'senc2.0',
#   'catv7',
#   'obsm1.0',
#   'choc3.0',
#   'manv1.0',
#   'mois7',
#   'jour24',
#   'hrmn15',
#   'lum3',
#   'agg2',
#   'int3',
#   'atm1',
#   'col6',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000427',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu21.0',
#   'an_nais2003.0',
#   'num_vehB02',
#   'catv1',
#   'obsm2.0',
#   'choc1.0',
#   'manv9.0',
#   'mois6',
#   'jour4',
#   'hrmn1945',
#   'lum1',
#   'agg2',
#   'int3',
#   'atm1',
#   'col3',
#   'mom4',
#   'catvopp7',
#   'catv_gen1',
#   'catvopp_gen2'],
#  ['Num_Acc201600000433',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1992.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv10',
#   'obsm2.0',
#   'choc3.0',
#   'manv19.0',
#   'mois2',
#   'jour2',
#   'hrmn1600',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col3',
#   'mom3',
#   'catvopp10',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000440',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1994.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois8',
#   'jour9',
#   'hrmn745',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col1',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000440',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1993.0',
#   'num_vehB02',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'manv13.0',
#   'mois8',
#   'jour9',
#   'hrmn745',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col1',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000441',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1997.0',
#   'num_vehA01',
#   'catv7',
#   'obs13.0',
#   'manv14.0',
#   'mois8',
#   'jour11',
#   'hrmn400',
#   'lum3',
#   'agg1',
#   'int1',
#   'atm1',
#   'col6',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000444',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu21.0',
#   'an_nais1973.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv33',
#   'obs12.0',
#   'choc1.0',
#   'manv1.0',
#   'mois8',
#   'jour28',
#   'hrmn1645',
#   'lum1',
#   'agg1',
#   'int6',
#   'atm1',
#   'col7',
#   'mom3',
#   'catvopp33',
#   'catv_gen1',
#   'catvopp_gen1'],
#  ['Num_Acc201600000445',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1961.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc2.0',
#   'manv1.0',
#   'mois9',
#   'jour23',
#   'hrmn815',
#   'lum2',
#   'agg2',
#   'int1',
#   'atm5',
#   'col3',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000452',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1981.0',
#   'num_vehB02',
#   'catv10',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois5',
#   'jour30',
#   'hrmn900',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm2',
#   'col1',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000456',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1949.0',
#   'num_vehA01',
#   'senc2.0',
#   'catv7',
#   'obs6.0',
#   'choc1.0',
#   'manv13.0',
#   'mois3',
#   'jour8',
#   'hrmn1115',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm1',
#   'col6',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000458',
#   'catu3',
#   'sexe2',
#   'locp4.0',
#   'actp3.0',
#   'etatp1.0',
#   'an_nais2002.0',
#   'num_vehA01',
#   'catv7',
#   'obsm1.0',
#   'choc3.0',
#   'mois1',
#   'jour14',
#   'hrmn800',
#   'lum2',
#   'agg2',
#   'int1',
#   'atm2',
#   'col6',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000458',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1988.0',
#   'num_vehA01',
#   'catv7',
#   'obsm1.0',
#   'choc3.0',
#   'mois1',
#   'jour14',
#   'hrmn800',
#   'lum2',
#   'agg2',
#   'int1',
#   'atm2',
#   'col6',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000459',
#   'place2.0',
#   'catu2',
#   'sexe2',
#   'secu11.0',
#   'an_nais1960.0',
#   'num_vehA01',
#   'catv7',
#   'obsm2.0',
#   'choc7.0',
#   'manv6.0',
#   'mois5',
#   'jour19',
#   'hrmn1815',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col3',
#   'mom4',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000459',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1990.0',
#   'num_vehA01',
#   'catv7',
#   'obsm2.0',
#   'choc7.0',
#   'manv6.0',
#   'mois5',
#   'jour19',
#   'hrmn1815',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col3',
#   'mom4',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000459',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1981.0',
#   'num_vehB02',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois5',
#   'jour19',
#   'hrmn1815',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col3',
#   'mom4',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000462',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1956.0',
#   'num_vehB02',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'manv16.0',
#   'mois8',
#   'jour26',
#   'hrmn1115',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col1',
#   'mom1',
#   'catvopp10',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000462',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1992.0',
#   'num_vehA01',
#   'catv10',
#   'obsm2.0',
#   'choc2.0',
#   'manv15.0',
#   'mois8',
#   'jour26',
#   'hrmn1115',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col1',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000462',
#   'place4.0',
#   'catu2',
#   'sexe2',
#   'secu11.0',
#   'an_nais1967.0',
#   'num_vehA01',
#   'catv10',
#   'obsm2.0',
#   'choc2.0',
#   'manv15.0',
#   'mois8',
#   'jour26',
#   'hrmn1115',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col1',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000465',
#   'catu3',
#   'sexe2',
#   'locp3.0',
#   'actp3.0',
#   'etatp1.0',
#   'an_nais2003.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv7',
#   'obsm1.0',
#   'choc2.0',
#   'manv1.0',
#   'mois12',
#   'jour15',
#   'hrmn1445',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm1',
#   'col6',
#   'mom3',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000469',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1964.0',
#   'num_vehB02',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois6',
#   'jour28',
#   'hrmn1745',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col3',
#   'mom3',
#   'catvopp33',
#   'catv_gen2',
#   'catvopp_gen1'],
#  ['Num_Acc201600000477',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1961.0',
#   'num_vehB02',
#   'catv14',
#   'mois1',
#   'jour14',
#   'hrmn1800',
#   'lum3',
#   'agg1',
#   'int1',
#   'atm2',
#   'col1',
#   'mom4',
#   'catvopp7',
#   'catv_gen3',
#   'catvopp_gen2'],
#  ['Num_Acc201600000479',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu21.0',
#   'an_nais1958.0',
#   'num_vehB02',
#   'catv2',
#   'obsm2.0',
#   'choc1.0',
#   'manv19.0',
#   'mois2',
#   'jour6',
#   'hrmn1000',
#   'lum1',
#   'agg1',
#   'int9',
#   'atm1',
#   'col3',
#   'mom1',
#   'catvopp7',
#   'catv_gen1',
#   'catvopp_gen2'],
#  ['Num_Acc201600000494',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu13.0',
#   'an_nais1974.0',
#   'num_vehB02',
#   'catv7',
#   'obsm2.0',
#   'choc2.0',
#   'manv1.0',
#   'mois10',
#   'jour13',
#   'hrmn1930',
#   'lum5',
#   'agg2',
#   'int1',
#   'atm2',
#   'col3',
#   'mom4',
#   'catvopp14',
#   'catv_gen2',
#   'catvopp_gen3'],
#  ['Num_Acc201600000496',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1981.0',
#   'num_vehA01',
#   'catv7',
#   'choc1.0',
#   'mois1',
#   'jour15',
#   'hrmn1230',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col4',
#   'mom2',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000499',
#   'place5.0',
#   'catu2',
#   'sexe2',
#   'secu11.0',
#   'an_nais1997.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc5.0',
#   'manv1.0',
#   'mois3',
#   'jour4',
#   'hrmn1830',
#   'lum2',
#   'agg1',
#   'int2',
#   'atm2',
#   'col5',
#   'mom4',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000500',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu21.0',
#   'an_nais1980.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv33',
#   'obsm2.0',
#   'choc1.0',
#   'manv9.0',
#   'mois5',
#   'jour18',
#   'hrmn1215',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col3',
#   'mom2',
#   'catvopp7',
#   'catv_gen1',
#   'catvopp_gen2'],
#  ['Num_Acc201600000505',
#   'place2.0',
#   'catu2',
#   'sexe2',
#   'secu11.0',
#   'an_nais1983.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'manv21.0',
#   'mois7',
#   'jour1',
#   'hrmn1630',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col1',
#   'mom3',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600000505',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1992.0',
# ...
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col5',
#   'mom3',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002241',
#   'place4.0',
#   'catu2',
#   'sexe2',
#   'secu11.0',
#   'an_nais1969.0',
#   'num_vehC03',
#   'senc2.0',
#   'catv7',
#   'obs13.0',
#   'choc7.0',
#   'manv21.0',
#   'mois12',
#   'jour9',
#   'hrmn1645',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col5',
#   'mom3',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002245',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1986.0',
#   'num_vehA01',
#   'catv7',
#   'obs14.0',
#   'choc1.0',
#   'manv2.0',
#   'mois3',
#   'jour3',
#   'hrmn815',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col5',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002245',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1972.0',
#   'num_vehC03',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois3',
#   'jour3',
#   'hrmn815',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col5',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002248',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1987.0',
#   'num_vehC03',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois7',
#   'jour6',
#   'hrmn800',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col4',
#   'mom1',
#   'catvopp10',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002249',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1991.0',
#   'num_vehA01',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'manv13.0',
#   'mois7',
#   'jour12',
#   'hrmn1815',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm2',
#   'col5',
#   'mom4',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002249',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1953.0',
#   'num_vehC03',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois7',
#   'jour12',
#   'hrmn1815',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm2',
#   'col5',
#   'mom4',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002249',
#   'place3.0',
#   'catu2',
#   'sexe1',
#   'secu11.0',
#   'an_nais2010.0',
#   'num_vehC03',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois7',
#   'jour12',
#   'hrmn1815',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm2',
#   'col5',
#   'mom4',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002254',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1996.0',
#   'num_vehC03',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'manv2.0',
#   'mois5',
#   'jour18',
#   'hrmn1915',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col5',
#   'mom4',
#   'catvopp10',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002255',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu21.0',
#   'an_nais1989.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv33',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois5',
#   'jour27',
#   'hrmn1815',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm1',
#   'col3',
#   'mom4',
#   'catvopp7',
#   'catv_gen1',
#   'catvopp_gen2'],
#  ['Num_Acc201600002256',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu21.0',
#   'an_nais1970.0',
#   'num_vehB02',
#   'catv1',
#   'obsm2.0',
#   'manv19.0',
#   'mois7',
#   'jour26',
#   'hrmn1400',
#   'lum1',
#   'agg1',
#   'int2',
#   'atm1',
#   'col3',
#   'mom3',
#   'catvopp10',
#   'catv_gen1',
#   'catvopp_gen2'],
#  ['Num_Acc201600002257',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu21.0',
#   'an_nais1971.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv1',
#   'obsm2.0',
#   'choc8.0',
#   'manv1.0',
#   'mois8',
#   'jour16',
#   'hrmn1000',
#   'lum1',
#   'agg1',
#   'int6',
#   'atm1',
#   'col3',
#   'mom1',
#   'catvopp7',
#   'catv_gen1',
#   'catvopp_gen2'],
#  ['Num_Acc201600002262',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1995.0',
#   'num_vehA01',
#   'catv3',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois5',
#   'jour17',
#   'hrmn1330',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col3',
#   'mom2',
#   'catvopp7',
#   'catvopp_gen2'],
#  ['Num_Acc201600002262',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1980.0',
#   'num_vehB02',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois5',
#   'jour17',
#   'hrmn1330',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col3',
#   'mom2',
#   'catvopp3',
#   'catv_gen2'],
#  ['Num_Acc201600002271',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1986.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois1',
#   'jour4',
#   'hrmn1615',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col1',
#   'mom3',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002273',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1959.0',
#   'num_vehB02',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois2',
#   'jour15',
#   'hrmn1945',
#   'lum5',
#   'agg2',
#   'int1',
#   'atm1',
#   'col1',
#   'mom4',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002275',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1963.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois4',
#   'jour20',
#   'hrmn1000',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col3',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002275',
#   'place4.0',
#   'catu2',
#   'sexe1',
#   'secu11.0',
#   'an_nais2006.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois4',
#   'jour20',
#   'hrmn1000',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col3',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002277',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu21.0',
#   'an_nais1965.0',
#   'num_vehA01',
#   'catv33',
#   'manv2.0',
#   'mois6',
#   'jour26',
#   'hrmn1745',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col7',
#   'mom3',
#   'catvopp33',
#   'catv_gen1',
#   'catvopp_gen1'],
#  ['Num_Acc201600002277',
#   'place2.0',
#   'catu2',
#   'sexe1',
#   'secu21.0',
#   'an_nais2004.0',
#   'num_vehA01',
#   'catv33',
#   'manv2.0',
#   'mois6',
#   'jour26',
#   'hrmn1745',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col7',
#   'mom3',
#   'catvopp33',
#   'catv_gen1',
#   'catvopp_gen1'],
#  ['Num_Acc201600002283',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1993.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv10',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois11',
#   'jour17',
#   'hrmn1830',
#   'lum3',
#   'agg1',
#   'int1',
#   'atm8',
#   'col1',
#   'mom4',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002286',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu21.0',
#   'an_nais1966.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv33',
#   'obsm2.0',
#   'choc4.0',
#   'manv1.0',
#   'mois1',
#   'jour8',
#   'hrmn1830',
#   'lum3',
#   'agg1',
#   'int1',
#   'atm1',
#   'col2',
#   'mom4',
#   'catvopp7',
#   'catv_gen1',
#   'catvopp_gen2'],
#  ['Num_Acc201600002294',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1991.0',
#   'num_vehA01',
#   'catv7',
#   'obs2.0',
#   'choc5.0',
#   'manv1.0',
#   'mois7',
#   'jour8',
#   'hrmn115',
#   'lum3',
#   'agg1',
#   'int1',
#   'atm1',
#   'col6',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002296',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1973.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'manv19.0',
#   'mois7',
#   'jour8',
#   'hrmn900',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col3',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002298',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu21.0',
#   'an_nais2001.0',
#   'num_vehA01',
#   'catv2',
#   'obsm9.0',
#   'mois8',
#   'jour14',
#   'hrmn1730',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col1',
#   'mom3',
#   'catvopp1',
#   'catv_gen1',
#   'catvopp_gen1'],
#  ['Num_Acc201600002299',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu13.0',
#   'an_nais1992.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc2.0',
#   'manv2.0',
#   'mois8',
#   'jour26',
#   'hrmn1500',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col2',
#   'mom3',
#   'catvopp1',
#   'catv_gen2',
#   'catvopp_gen1'],
#  ['Num_Acc201600002302',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1975.0',
#   'num_vehA01',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc2.0',
#   'manv1.0',
#   'mois3',
#   'jour11',
#   'hrmn1645',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col1',
#   'mom3',
#   'catvopp1',
#   'catv_gen2',
#   'catvopp_gen1'],
#  ['Num_Acc201600002305',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1990.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois11',
#   'jour22',
#   'hrmn1830',
#   'lum3',
#   'agg1',
#   'int1',
#   'atm1',
#   'col3',
#   'mom4',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002311',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1978.0',
#   'num_vehB02',
#   'catv17',
#   'obsm2.0',
#   'choc5.0',
#   'manv15.0',
#   'mois8',
#   'jour23',
#   'hrmn800',
#   'lum1',
#   'agg1',
#   'int4',
#   'atm1',
#   'col2',
#   'mom1',
#   'catvopp33',
#   'catv_gen3',
#   'catvopp_gen1'],
#  ['Num_Acc201600002315',
#   'place4.0',
#   'catu2',
#   'sexe2',
#   'secu11.0',
#   'an_nais2002.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois9',
#   'jour30',
#   'hrmn1930',
#   'lum2',
#   'agg1',
#   'int1',
#   'atm1',
#   'col1',
#   'mom4',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002317',
#   'catu3',
#   'sexe1',
#   'locp2.0',
#   'actp9.0',
#   'etatp2.0',
#   'an_nais1967.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv7',
#   'obsm1.0',
#   'choc2.0',
#   'manv1.0',
#   'mois10',
#   'jour31',
#   'hrmn1645',
#   'lum1',
#   'agg2',
#   'int9',
#   'atm1',
#   'col6',
#   'mom3',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002317',
#   'catu3',
#   'sexe1',
#   'locp2.0',
#   'actp9.0',
#   'etatp2.0',
#   'an_nais1994.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv7',
#   'obsm1.0',
#   'choc2.0',
#   'manv1.0',
#   'mois10',
#   'jour31',
#   'hrmn1645',
#   'lum1',
#   'agg2',
#   'int9',
#   'atm1',
#   'col6',
#   'mom3',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002319',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu21.0',
#   'an_nais1999.0',
#   'num_vehB02',
#   'catv31',
#   'obsm2.0',
#   'choc7.0',
#   'manv1.0',
#   'mois11',
#   'jour14',
#   'hrmn1845',
#   'lum5',
#   'agg2',
#   'int1',
#   'atm1',
#   'col3',
#   'mom4',
#   'catvopp7',
#   'catv_gen1',
#   'catvopp_gen2'],
#  ['Num_Acc201600002320',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu21.0',
#   'an_nais1990.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv33',
#   'choc3.0',
#   'manv15.0',
#   'mois11',
#   'jour24',
#   'hrmn1315',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm1',
#   'col7',
#   'mom2',
#   'catvopp33',
#   'catv_gen1',
#   'catvopp_gen1'],
#  ['Num_Acc201600002323',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu23.0',
#   'an_nais1983.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv30',
#   'obsm2.0',
#   'choc1.0',
#   'manv16.0',
#   'mois12',
#   'jour2',
#   'hrmn1530',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm1',
#   'col2',
#   'mom3',
#   'catvopp30',
#   'catv_gen1',
#   'catvopp_gen1'],
#  ['Num_Acc201600002326',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1989.0',
#   'num_vehB02',
#   'catv7',
#   'obsm2.0',
#   'choc2.0',
#   'manv16.0',
#   'mois9',
#   'jour25',
#   'hrmn1700',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm1',
#   'col3',
#   'mom3',
#   'catvopp30',
#   'catv_gen2',
#   'catvopp_gen1'],
#  ['Num_Acc201600002327',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1983.0',
#   'num_vehB02',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'manv13.0',
#   'mois11',
#   'jour4',
#   'hrmn1000',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm2',
#   'col5',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002327',
#   'place2.0',
#   'catu2',
#   'sexe2',
#   'secu11.0',
#   'an_nais1980.0',
#   'num_vehB02',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'manv13.0',
#   'mois11',
#   'jour4',
#   'hrmn1000',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm2',
#   'col5',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002327',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1984.0',
#   'num_vehC03',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois11',
#   'jour4',
#   'hrmn1000',
#   'lum1',
#   'agg2',
#   'int1',
#   'atm2',
#   'col5',
#   'mom1',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002329',
#   'place4.0',
#   'catu2',
#   'sexe1',
#   'secu11.0',
#   'an_nais1970.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'manv2.0',
#   'mois1',
#   'jour30',
#   'hrmn2345',
#   'lum3',
#   'agg1',
#   'int1',
#   'atm2',
#   'col2',
#   'mom5',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002330',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1969.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc2.0',
#   'mois2',
#   'jour13',
#   'hrmn1615',
#   'lum1',
#   'agg1',
#   'int2',
#   'atm2',
#   'col3',
#   'mom3',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002339',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1958.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv17',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois5',
#   'jour9',
#   'hrmn1515',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col1',
#   'mom3',
#   'catvopp7',
#   'catv_gen3',
#   'catvopp_gen2'],
#  ['Num_Acc201600002342',
#   'place2.0',
#   'catu2',
#   'sexe2',
#   'secu11.0',
#   'an_nais1973.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc3.0',
#   'manv1.0',
#   'mois6',
#   'jour22',
#   'hrmn1930',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col1',
#   'mom4',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002343',
#   'place1.0',
#   'catu1',
#   'sexe2',
#   'secu11.0',
#   'an_nais1935.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv7',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois7',
#   'jour22',
#   'hrmn1115',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col1',
#   'mom1',
#   'catvopp33',
#   'catv_gen2',
#   'catvopp_gen1'],
#  ['Num_Acc201600002346',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1976.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc7.0',
#   'manv1.0',
#   'mois11',
#   'jour2',
#   'hrmn1200',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col3',
#   'mom2',
#   'catvopp10',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002346',
#   'place5.0',
#   'catu2',
#   'sexe1',
#   'secu11.0',
#   'an_nais2003.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc7.0',
#   'manv1.0',
#   'mois11',
#   'jour2',
#   'hrmn1200',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col3',
#   'mom2',
#   'catvopp10',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002346',
#   'place5.0',
#   'catu2',
#   'sexe2',
#   'secu11.0',
#   'an_nais2004.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc7.0',
#   'manv1.0',
#   'mois11',
#   'jour2',
#   'hrmn1200',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col3',
#   'mom2',
#   'catvopp10',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002346',
#   'place5.0',
#   'catu2',
#   'sexe1',
#   'secu11.0',
#   'an_nais2009.0',
#   'num_vehB02',
#   'senc2.0',
#   'catv7',
#   'obsm2.0',
#   'choc7.0',
#   'manv1.0',
#   'mois11',
#   'jour2',
#   'hrmn1200',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col3',
#   'mom2',
#   'catvopp10',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002349',
#   'place2.0',
#   'catu2',
#   'sexe2',
#   'secu21.0',
#   'an_nais1997.0',
#   'num_vehB02',
#   'senc1.0',
#   'catv2',
#   'obsm2.0',
#   'choc2.0',
#   'manv1.0',
#   'mois6',
#   'jour19',
#   'hrmn1545',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col3',
#   'mom3',
#   'catvopp2',
#   'catv_gen1',
#   'catvopp_gen1'],
#  ['Num_Acc201600002351',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu11.0',
#   'an_nais1991.0',
#   'num_vehA01',
#   'senc1.0',
#   'catv7',
#   'obs2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois7',
#   'jour2',
#   'hrmn2000',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col6',
#   'mom4',
#   'catvopp7',
#   'catv_gen2',
#   'catvopp_gen2'],
#  ['Num_Acc201600002352',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu21.0',
#   'an_nais1963.0',
#   'num_vehB02',
#   'catv2',
#   'obsm2.0',
#   'choc1.0',
#   'manv1.0',
#   'mois8',
#   'jour22',
#   'hrmn1900',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col3',
#   'mom4',
#   'catvopp1',
#   'catv_gen1',
#   'catvopp_gen1'],
#  ['Num_Acc201600002352',
#   'place1.0',
#   'catu1',
#   'sexe1',
#   'secu21.0',
#   'an_nais2001.0',
#   'num_vehA01',
#   'catv1',
#   'obsm2.0',
#   'choc8.0',
#   'manv15.0',
#   'mois8',
#   'jour22',
#   'hrmn1900',
#   'lum1',
#   'agg1',
#   'int1',
#   'atm1',
#   'col3',
#   'mom4',
#   'catvopp2',
#   'catv_gen1',
#   'catvopp_gen1'],
#  ...]

# %% [markdown]
# On essaie de prédire la vraie catégorie

# %%
### Préparation des données
X_train, X_test, y_train, y_test = train_test_split(merged_data_sans_grav, y, test_size=0.1)


train_X = X_train.as_matrix()
test_X = X_test.as_matrix()
train_y = y_train


### Parametres
max_depth=10
learning_rate=0.01
n_estimators=100
silent=True
objective='binary:logistic'
booster='gblinear'
n_jobs=100
nthread=None
gamma=0.1
min_child_weight=1
max_delta_step=0
subsample=1
colsample_bytree=1
colsample_bylevel=1
reg_alpha=0.5
reg_lambda=1
scale_pos_weight=1
base_score=0.5
random_state=0
seed=None
missing=None


### Training
gbm = xgb.XGBClassifier(max_depth = max_depth, 
                        n_estimators = n_estimators, 
                        learning_rate = learning_rate,
                        gamma = gamma,
                        reg_alpha= reg_alpha).fit(train_X, train_y)


### Predictions
predictions = gbm.predict(test_X)


### Resultats
pourcentage = (predictions - y_test).replace(to_replace = [-4,-3,-2,-1,1,2,3,4], value = -1)
print(1 + sum(pourcentage)/len(pourcentage))
# Out:
# 0.587600246761

# %% [markdown]
# Ici on essaie juste de prédire grave / pas grave

# %%
X_train, X_test, y_train, y_test = train_test_split(merged_data_sans_grav, y, test_size=0.25)

cat1 = [1]
cat2 = [2,3,4]

y_train = y_train.replace(cat1,0)
y_train = y_train.replace(cat2,1)
y_test = y_test.replace(cat1,0)
y_test = y_test.replace(cat2,1)

train_X = X_train.as_matrix()
test_X = X_test.as_matrix()
train_y = y_train

# You can experiment with many other options here, using the same .fit() and .predict()
# methods; see http://scikit-learn.org
# This example uses the current build of XGBoost, from https://github.com/dmlc/xgboost
gbm = xgb.XGBClassifier(max_depth = max_depth, 
                        n_estimators = n_estimators, 
                        learning_rate = learning_rate,
                        gamma = gamma,
                        reg_alpha= reg_alpha).fit(train_X, train_y)
predictions = gbm.predict(test_X)

pourcentage = (predictions - y_test).replace(to_replace = [-4,-3,-2,-1,1,2,3,4], value = -1)
print(1 + sum(pourcentage)/len(pourcentage))
# Out:
# 0.815175817397

# %%
print(X_train.shape,
X_test.shape, y_train.shape, y_test.shape
     )
# Out:
# (24312, 27) (8105, 27) (24312,) (8105,)

# %%
length = len(predictions)
y_test_liste = list(y_test)
ok_0 = 0
ok_1 = 0
err_pr = 0
err_sec = 0
for iteration in range(0,length):
    if predictions[iteration] == 0:
        if y_test_liste[iteration] == 0:
            ok_0 += 1
        else:
            err_sec += 1
    else:
        if y_test_liste[iteration] == 1:
            ok_1 += 1
        else:
            err_pr +=1
print(ok_0,ok_1,err_pr, err_sec)
labels = ['ok_0','ok_1','err_pr', 'err_sec']
values = [ok_0,ok_1,err_pr, err_sec]
plt.pie(values, labels = labels)
plt.title('explication prediction' )
plt.show()
plt.close()
# Out:
# 1716 4891 1161 337

# %%
y_sexe = merged_data.sexe
merged_data_sans_sexe = merged_data.drop(['sexe'],axis = 1)


X_train, X_test, y_train, y_test = train_test_split(merged_data_sans_grav, y, test_size=0.1)

cat1 = [1,3,4]
cat2 = [2]

y_train = y_train.replace(cat1,0)
y_train = y_train.replace(cat2,1)
y_test = y_test.replace(cat1,0)
y_test = y_test.replace(cat2,1)

train_X = X_train.as_matrix()
test_X = X_test.as_matrix()
train_y = y_train

# You can experiment with many other options here, using the same .fit() and .predict()
# methods; see http://scikit-learn.org
# This example uses the current build of XGBoost, from https://github.com/dmlc/xgboost
gbm = xgb.XGBClassifier(max_depth = max_depth, 
                        n_estimators = n_estimators, 
                        learning_rate = learning_rate,
                        gamma = gamma,
                        reg_alpha= reg_alpha).fit(train_X, train_y)
predictions = gbm.predict_proba(test_X)

# %%
def TP(theta,pred,result):
    count = 0
    i = 0
    for x in (result):
        if pred[i][1] > theta and x == 1:
            count += 1
        i += 1
    return count

def FP(theta,pred,result):
    count = 0
    i = 0
    for x in (result):
        if pred[i][1] >= theta and x == 0:
            count += 1
        i += 1
    return count

def TN(theta,pred,result):
    count = 0
    i = 0
    for x in (result):
        if pred[i][1] < theta and x == 0:
            count += 1
        i += 1
    return count

def FN(theta,pred,result):
    count = 0
    i = 0
    for x in (result):
        if pred[i][1] < theta and x == 1:
            count += 1
        i += 1
    return count

# %%
class ROC_curves:
    def __init__(self, pred = predictions, res = y_test, gran = 101):
        x = []
        y = []
        for j in range(0,gran):
            tn = TN(j/(gran-1),pred,res)
            neg = tn + FP(j/(gran-1),pred,res)
            tp = TP(j/(gran-1),pred,res)
            pos = tp + FN(j/(gran-1),pred,res)

            if neg == 0:
                x.append(0)
            else:
                x.append(tn / neg)
            if pos == 0:
                y.append(0)
            else:
                y.append(tp / pos)
        self.rocx = x
        self.rocy = y
    def plot_it(self):
        plt.plot(self.rocx,self.rocy)
        plt.show()

# %%
ROC = ROC_curves()

# %%
ROC.plot_it()


predictions = gbm.predict(X_test)
length = len(predictions)
y_test_liste = list(y_test)
ok_0 = 0
ok_1 = 0
err_pr = 0
err_sec = 0
for iteration in range(0,length):
    if predictions[iteration] == 0:
        if y_test_liste[iteration] == 0:
            ok_0 += 1
        else:
            err_sec += 1
    else:
        if y_test_liste[iteration] == 1:
            ok_1 += 1
        else:
            err_pr +=1
print(ok_0,ok_1,err_pr, err_sec)
labels = ['ok_0','ok_1','err_pr', 'err_sec']
values = [ok_0,ok_1,err_pr, err_sec]
plt.pie(values, labels = labels)
plt.title('explication prediction' )
plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-3def473af3bc> in <module>()
#       2
#       3
# ----> 4 predictions = gbm.predict(X_test)
#       5 length = len(predictions)
#       6 y_test_liste = list(y_test)
#
# /Users/ppx/anaconda3/lib/python3.6/site-packages/xgboost/sklearn.py in predict(self, data, output_margin, ntree_limit)
#     463         class_probs = self.booster().predict(test_dmatrix,
#     464                                              output_margin=output_margin,
# --> 465                                              ntree_limit=ntree_limit)
#     466         if len(class_probs.shape) > 1:
#     467             column_indexes = np.argmax(class_probs, axis=1)
#
# /Users/ppx/anaconda3/lib/python3.6/site-packages/xgboost/core.py in predict(self, data, output_margin, ntree_limit, pred_leaf)
#     937             option_mask |= 0x02
#     938
# --> 939         self._validate_features(data)
#     940
#     941         length = ctypes.c_ulong()
#
# /Users/ppx/anaconda3/lib/python3.6/site-packages/xgboost/core.py in _validate_features(self, data)
#    1177
#    1178                 raise ValueError(msg.format(self.feature_names,
# -> 1179                                             data.feature_names))
#    1180
#    1181     def get_split_value_histogram(self, feature, fmap='', bins=None, as_pandas=True):
#
# ValueError: feature_names mismatch: ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'f21', 'f22', 'f23', 'f24', 'f25', 'f26'] ['place', 'catu', 'sexe', 'secu', 'locp', 'actp', 'etatp', 'an_nais', 'senc', 'catv', 'occutc', 'obs', 'obsm', 'choc', 'manv', 'mois', 'jour', 'hrmn', 'lum', 'agg', 'int', 'atm', 'col', 'mom', 'catvopp', 'catv_gen', 'catvopp_gen']
# expected f19, f9, f7, f0, f2, f3, f18, f16, f26, f23, f21, f15, f4, f20, f6, f10, f14, f12, f24, f8, f11, f13, f1, f17, f25, f5, f22 in input data
# training data did not have the following fields: jour, mom, mois, catu, secu, locp, occutc, an_nais, choc, place, senc, obs, lum, catv_gen, agg, col, actp, etatp, int, obsm, hrmn, catvopp_gen, manv, sexe, catv, atm, catvopp

# %%
sum(y_train)/len(y_train)

# %%
clf = LinearSVC(random_state=0, C = 123)
clf.fit(X_train,y_train)

# %%
X_test.head()

# %%
predictors = ['catu', 'choc', 'mom', 'catv_gen','catvopp_gen']
X_train = X_train[predictors]
X_test = X_test[predictors]
clf = LinearSVC( C = 123, max_iter=12)
clf.fit(X_train,y_train)

predictions = clf.predict(X_test)
length = len(predictions)
y_test_liste = list(y_test)
ok_0 = 0
ok_1 = 0
err_pr = 0
err_sec = 0
for iteration in range(0,length):
    if predictions[iteration] == 0:
        if y_test_liste[iteration] == 0:
            ok_0 += 1
        else:
            err_sec += 1
    else:
        if y_test_liste[iteration] == 1:
            ok_1 += 1
        else:
            err_pr +=1
print(ok_0,ok_1,err_pr, err_sec)
labels = ['ok_0','ok_1','err_pr', 'err_sec']
values = [ok_0,ok_1,err_pr, err_sec]
plt.pie(values, labels = labels)
plt.title('explication prediction' )
plt.show()
plt.close()

# %%
set(predictions)
sum(predictions)
